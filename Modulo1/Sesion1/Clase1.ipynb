# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

import sklearn

libs = {"NumPy": np.__version__, "Pandas": pd.__version__,

"Matplotlib": plt.matplotlib.__version__,

"Seaborn": sns.__version__, "Scikit-learn": sklearn.__version__}

for nombre, version in libs.items():

    print(f" ✓ {nombre:15} v{version}")
# Out:
#  ✓ NumPy           v2.2.2
#  ✓ Pandas          v2.2.3
#  ✓ Matplotlib      v3.10.8
#  ✓ Seaborn         v0.13.2
#  ✓ Scikit-learn    v1.8.0
